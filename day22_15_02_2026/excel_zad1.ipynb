# %% [markdown]
# # Zadania z pracy Excel
#
# ## Kolejny
# ### Kolejny
#
# nowa linia<br>
# nowa linia\
# nowa linia
#
# **pogrubiony**\
# *kursywa*
#
# [OpenAI](https://openai.com)\
# ![OpenAI](https://openai.com/favicon.ico)
#
# ![Logo](images/logo.png)
#
# ***pogrubienie + kursywa***\
# ~~przekreślenie~~
#
# - element1
# - element2
#     - podpunkt
# 1. pierwszy
# 2. drugi
# 3. trzeci
#
# ---
